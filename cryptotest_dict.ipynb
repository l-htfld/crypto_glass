# %%
import aiohttp
import asyncio
import nest_asyncio
import json
import logging
from datetime import datetime
from sortedcontainers import SortedDict
import backoff
from typing import Dict, List
import os

# %%
# Настройка базовой конфигурации логирования
logging.basicConfig(
    level=logging.INFO, # Уровень логирования
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[ # Обработчики, которые определяют, куда будут отправляться сообщения
        logging.StreamHandler(),
        logging.FileHandler('orderbook.log')
    ]
)
logger = logging.getLogger(__name__)

# %%
class OrderBookManager:
    def __init__(self):
        self.orderbooks: Dict[str, Dict] = {} # Создаем пустой словарь для хранения стаканов по ключу 'inst_id'
        self.lock = asyncio.Lock() # Создаем объект блокировки для асинхронной работы с данными
        self.data_dir = "orderbook_data"
        if not os.path.exists(self.data_dir):
            os.makedirs(self.data_dir)

    async def process_book_data(self, inst_id: str, data: dict): # Извлекаем необходимые данные из входящего сообщения
        action = data.get('action', 'update')
        bids = data.get('bids', [])
        asks = data.get('asks', [])
        ts = data.get('ts', datetime.now().isoformat()) # Время обновления стакана

        async with self.lock:
            if inst_id not in self.orderbooks or action == 'snapshot': # Если стакан для инструмента не существует или пришел полный снапшот
                self.orderbooks[inst_id] = { # Инициализируем новый стакан
                    'bids': SortedDict(),
                    'asks': SortedDict(),
                    'ts': ts
                }
                for price, qty, *_ in bids: # Добавляем новые заявки на покупку в стакан
                    self.orderbooks[inst_id]['bids'][float(price)] = float(qty)
                for price, qty, *_ in asks: # Добавляем новые заявки на продажу в стакан
                    self.orderbooks[inst_id]['asks'][float(price)] = float(qty)
            else: # Обрабатываем изменения (дельты) в стакане
                for price, qty, *_ in bids:
                    price_f = float(price)
                    qty_f = float(qty)
                    if qty_f == 0: # Если количество равно 0, убираем заявку
                        self.orderbooks[inst_id]['bids'].pop(price_f, None)
                    else: # Обновляем заявку
                        self.orderbooks[inst_id]['bids'][price_f] = qty_f
                
                for price, qty, *_ in asks: 
                    price_f = float(price)
                    qty_f = float(qty)
                    if qty_f == 0:
                        self.orderbooks[inst_id]['asks'].pop(price_f, None)
                    else:
                        self.orderbooks[inst_id]['asks'][price_f] = qty_f
                self.orderbooks[inst_id]['ts'] = ts # Обновляем время последнего изменения

            # Сохраняем данные в файл
            self.save_orderbook(inst_id)

    def save_orderbook(self, inst_id: str):
        # Сохраняем orderbook в формате JSON
        book = self.orderbooks.get(inst_id)
        if book:
            file_path = os.path.join(self.data_dir, f"{inst_id}_orderbook.json")
            with open(file_path, "w") as f:
                json.dump(book, f, indent=4)

    def get_top(self, inst_id: str, depth: int = 5) -> dict:
        # Метод для получения топовых заявок из стакана
        book = self.orderbooks.get(inst_id)
        return {
            'bids': list(reversed(book['bids'].items()))[:depth] if book else [],
            'asks': list(book['asks'].items())[:depth] if book else [],
            'ts': book['ts'] if book else None
        }

# %%
class OKXOrderBookCollector:
    def __init__(self):
        self.REST_URL = "https://www.okx.com/api/v5/public/instruments"
        self.WS_URL = "wss://ws.okx.com:8443/ws/v5/public"
        self.book_manager = OrderBookManager() # Менеджер для обработки и хранения данных о стаканах
        self.instruments: List[str] = [] # Список инструментов, на которые будем подписываться
        self.ws: aiohttp.ClientWebSocketResponse = None # WebSocket соединение
        self.session: aiohttp.ClientSession = None # HTTP сессия для запросов
        self.running = True

    @backoff.on_exception(backoff.expo, Exception, max_time=300) # Получение списка инструментов через REST API
    async def get_instruments(self):
        async with aiohttp.ClientSession() as session:
            async with session.get(self.REST_URL, params={'instType': 'SPOT'}) as resp:
                data = await resp.json()
                return [inst['instId'] for inst in data.get('data', [])]

    @backoff.on_exception(backoff.expo, aiohttp.ClientError, max_time=300)
    async def connect_websocket(self): # Подключение к WebSocket серверу
        if self.session is None or self.session.closed: # Если сессия закрыта, создаем новую
            self.session = aiohttp.ClientSession()
        self.ws = await self.session.ws_connect(
            self.WS_URL,
            heartbeat=30, # Период отправки heartbeat сообщений
            receive_timeout=60 # Время ожидания сообщений
        )
        logger.info("WebSocket connection established")

    async def subscribe_to_instruments(self):
        # Подписка на инструменты через WebSocket
        chunks = [self.instruments[i:i+20] for i in range(0, len(self.instruments), 20)]
        for chunk in chunks:
            sub_msg = {
                "op": "subscribe",
                "args": [{"channel": "books", "instId": inst} for inst in chunk]
            }
            await self.ws.send_json(sub_msg)
            logger.info(f"Subscribed to {len(chunk)} instruments")

    async def handle_message(self, msg: str):
        # Обработка сообщений, получаемых через WebSocket
        try:
            data = json.loads(msg) # Десериализация сообщения из JSON
            if 'event' in data:
                logger.info(f"Subscription update: {data}") # Логируем обновление подписки
                return

            if 'data' not in data or 'arg' not in data:
                return

            inst_id = data['arg']['instId']
            book_data = data['data'][0]
            await self.book_manager.process_book_data(inst_id, {
                'action': book_data.get('action', 'update'),
                'bids': book_data['bids'],
                'asks': book_data['asks'],
                'ts': book_data.get('ts')
            })

        except Exception as e:
            logger.error(f"Error processing message: {str(e)}", exc_info=True)

    async def start(self): # Основной метод для запуска процесса сбора данных
        try:
            self.instruments = await self.get_instruments() # Получаем список инструментов
            logger.info(f"Loaded {len(self.instruments)} instruments") # Логируем количество загруженных инструментов

            while self.running:
                try:
                    await self.connect_websocket() # Подключаемся к WebSocket
                    await self.subscribe_to_instruments() # Подписываемся на инструменты

                    async for msg in self.ws: # Получаем сообщения от WebSocket
                        if not self.running:
                            break
                        if msg.type == aiohttp.WSMsgType.TEXT: # Если тип сообщения - текст, обрабатываем его
                            await self.handle_message(msg.data)
                        elif msg.type == aiohttp.WSMsgType.PING: # Если получен ping, отвечаем pong
                            await self.ws.pong()
                        elif msg.type in (aiohttp.WSMsgType.CLOSED, aiohttp.WSMsgType.ERROR): # Если соединение закрыто или ошибка
                            raise ConnectionError("WebSocket connection closed")

                except (aiohttp.ClientError, ConnectionError) as e:
                    logger.warning(f"Connection error: {str(e)}, reconnecting...") # Логируем ошибку соединения и повторное подключение
                except Exception as e:
                    logger.error(f"Unexpected error: {str(e)}", exc_info=True) # Логируем другие неожиданные ошибки
                finally:
                    await self.close_websocket() # Закрываем WebSocket соединение
                    await asyncio.sleep(5) # Ждем перед повторным подключением

        except KeyboardInterrupt:
            logger.info("Shutting down gracefully...") # Логируем завершение работы
        finally:
            await self.close() # Закрываем все ресурсы

    async def close_websocket(self):
        # Закрытие WebSocket соединения
        if self.ws and not self.ws.closed:
            await self.ws.close()
            self.ws = None

    async def close(self): # Завершаем работу и закрываем все соединения
        self.running = False
        await self.close_websocket()
        if self.session and not self.session.closed:
            await self.session.close()
            self.session = None

    async def monitor_books(self, interval: int = 10):
        # Мониторим топовые заявки
        while self.running:
            for inst_id in (self.instruments[:3] if self.instruments else []):
                top = self.book_manager.get_top(inst_id)
                if top['ts']: # Логируем топовые заявки
                    logger.info(
                        f"{inst_id} | Bids: {[f'{p:.2f}:{q:.4f}' for p, q in top['bids'][:3]]} | "
                        f"Asks: {[f'{p:.2f}:{q:.4f}' for p, q in top['asks'][:3]]}"
                    )
            await asyncio.sleep(interval)

async def main(): # Главная асинхронная функция для запуска процесса
    collector = OKXOrderBookCollector()
    await asyncio.gather(
        collector.start(),
        collector.monitor_books()
    )

# %%
if __name__ == "__main__":
    import nest_asyncio
    nest_asyncio.apply()
    await main()
# Out:
# 2025-02-10 16:28:46,539 - INFO - Loaded 710 instruments
# 2025-02-10 16:28:47,345 - INFO - WebSocket connection established
# 2025-02-10 16:28:47,346 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,348 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,350 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,353 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,356 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,357 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,360 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,362 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,365 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,368 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,371 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,373 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,376 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,379 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,382 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,388 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,390 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,394 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,396 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,399 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,401 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,404 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,406 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,408 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,411 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,417 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,424 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,427 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,429 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,433 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,439 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,442 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,447 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,453 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,456 - INFO - Subscribed to 20 instruments
# 2025-02-10 16:28:47,459 - INFO - Subscribed to 10 instruments
# 2025-02-10 16:28:47,586 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BTC-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,587 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ETH-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,589 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SOL-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,591 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'DOGE-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,593 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'XRP-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,594 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'TRUMP-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,598 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BERA-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,602 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'AAVE-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,604 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ACH-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,606 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ANIME-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,607 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ARB-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,610 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ATH-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,612 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'AVAX-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,614 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BANANA-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,618 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BOME-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,622 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'CITY-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,623 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'COMP-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,625 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'CRV-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,627 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'DAI-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,630 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'DEGEN-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,631 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'DUCK-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,635 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ENS-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,637 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ETHFI-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,639 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'GOAT-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,646 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'GPT-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,654 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'JST-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,658 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'LINK-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,661 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'LTC-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,665 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ME-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,669 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'MEME-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,673 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'MERL-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,675 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'MEW-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,677 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'MKR-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,679 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'OL-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,682 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'OP-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,684 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'PENGU-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,687 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'PEPE-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,689 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'PIXEL-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,694 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'PRCL-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,697 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'RADAR-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,702 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'RAY-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,705 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'S-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,712 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SAFE-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,715 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SHIB-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,719 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SSV-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,721 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SUI-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,723 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ULTI-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,727 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'UNI-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,729 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'USDT-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,732 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'VELODROME-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,736 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'WIN-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,739 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'WLD-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,742 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'XR-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,744 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ZETA-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,745 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ZKJ-USD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,748 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'USDT-SGD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,755 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'USDC-SGD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,758 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BTC-AUD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,761 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ETH-AUD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,763 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SOL-AUD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,770 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'XRP-AUD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,774 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'TRUMP-AUD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,776 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'USDT-AUD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,778 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'USDC-AUD'}, 'connId': 'ee03ff34'}
# 2025-02-10 16:28:47,782 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BTC
- INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'WAXP-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,275 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'WBTC-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,277 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'WIF-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,282 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'WLD-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,285 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'XCH-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,286 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'XLM-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,288 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'XNO-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,289 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'XTZ-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,292 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'YFI-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,294 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'YGG-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,297 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ZBCN-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,301 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ZENT-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,304 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ZERO-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,306 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ZETA-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,309 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ZEUS-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,312 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ZIL-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,314 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ZK-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,317 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ZRO-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,319 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ZRX-USDC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,341 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ETH-BTC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,352 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'OKB-BTC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,355 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SOL-BTC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,363 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BCH-BTC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,366 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BSV-BTC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,368 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'LTC-BTC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,370 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'STX-BTC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,373 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'WBTC-BTC'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,375 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SOL-ETH'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,376 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BETH-ETH'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,379 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'STETH-ETH'}, 'connId': '1f5a7b2b'}
# 2025-02-10 16:29:31,381 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'OKSOL-SOL'}, 'connId': '1f5a7b2b'}
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[12], line 4
#       2 import nest_asyncio
#       3 nest_asyncio.apply()
# ----> 4 await main()
#
# Cell In[11], line 119, in main()
#     117 async def main():
#     118     collector = OKXOrderBookCollector()
# --> 119     await asyncio.gather(
#     120         collector.start(),
#     121         collector.monitor_books()
#     122     )
#
# File c:\Python312\Lib\asyncio\tasks.py:385, in Task.__wakeup(self, future)
#     383 def __wakeup(self, future):
#     384     try:
# --> 385         future.result()
#     386     except BaseException as exc:
#     387         # This may also be a cancellation.
#     388         self.__step(exc)
#
# File c:\Python312\Lib\asyncio\tasks.py:316, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     314         result = coro.send(None)
#     315     else:
# --> 316         result = coro.throw(exc)
#     317 except StopIteration as exc:
#     318     if self._must_cancel:
#     319         # Task is cancelled right before coro stops.
#
# Cell In[11], line 115, in OKXOrderBookCollector.monitor_books(self, interval)
#     110     if top['ts']:
#     111         logger.info(
#     112             f"{inst_id} | Bids: {[f'{p:.2f}:{q:.4f}' for p, q in top['bids'][:3]]} | "
#     113             f"Asks: {[f'{p:.2f}:{q:.4f}' for p, q in top['asks'][:3]]}"
#     114         )
# --> 115 await asyncio.sleep(interval)
#
# File c:\Python312\Lib\asyncio\tasks.py:665, in sleep(delay, result)
#     661 h = loop.call_later(delay,
#     662                     futures._set_result_unless_cancelled,
#     663                     future, result)
#     664 try:
# --> 665     return await future
#     666 finally:
#     667     h.cancel()
#
# File c:\Python312\Lib\asyncio\futures.py:287, in Future.__await__(self)
#     285 if not self.done():
#     286     self._asyncio_future_blocking = True
# --> 287     yield self  # This tells Task to wait for completion.
#     288 if not self.done():
#     289     raise RuntimeError("await wasn't used with future")
#
# File c:\Python312\Lib\asyncio\tasks.py:385, in Task.__wakeup(self, future)
#     383 def __wakeup(self, future):
#     384     try:
# --> 385         future.result()
#     386     except BaseException as exc:
#     387         # This may also be a cancellation.
#     388         self.__step(exc)
#
# File c:\Python312\Lib\asyncio\futures.py:198, in Future.result(self)
#     196 if self._state == _CANCELLED:
#     197     exc = self._make_cancelled_error()
# --> 198     raise exc
#     199 if self._state != _FINISHED:
#     200     raise exceptions.InvalidStateError('Result is not ready.')
#
# CancelledError:
