# %%
import aiohttp
import asyncio
import nest_asyncio
import json
import logging
from datetime import datetime
from sortedcontainers import SortedDict
import backoff
from typing import Dict, List
import os

# %%
# Настройка базовой конфигурации логирования
logging.basicConfig(
    level=logging.INFO, # Уровень логирования
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[ # Обработчики, которые определяют, куда будут отправляться сообщения
        logging.StreamHandler(),
        logging.FileHandler('orderbook.log')
    ]
)
logger = logging.getLogger(__name__)

# %%
class OrderBookManager:
    def __init__(self):
        self.orderbooks: Dict[str, Dict] = {} # Создаем пустой словарь для хранения стаканов по ключу 'inst_id'
        self.lock = asyncio.Lock() # Создаем объект блокировки для асинхронной работы с данными
        self.data_dir = "orderbook_data"
        if not os.path.exists(self.data_dir):
            os.makedirs(self.data_dir)

    async def process_book_data(self, inst_id: str, data: dict): # Извлекаем необходимые данные из входящего сообщения
        action = data.get('action', 'update')
        bids = data.get('bids', [])
        asks = data.get('asks', [])
        ts = data.get('ts', datetime.now().isoformat()) # Время обновления стакана

        async with self.lock:
            if inst_id not in self.orderbooks or action == 'snapshot': # Если стакан для инструмента не существует или пришел полный снапшот
                self.orderbooks[inst_id] = { # Инициализируем новый стакан
                    'bids': SortedDict(),
                    'asks': SortedDict(),
                    'ts': ts
                }
                for price, qty, *_ in bids: # Добавляем новые заявки на покупку в стакан
                    self.orderbooks[inst_id]['bids'][float(price)] = float(qty)
                for price, qty, *_ in asks: # Добавляем новые заявки на продажу в стакан
                    self.orderbooks[inst_id]['asks'][float(price)] = float(qty)
            else: # Обрабатываем изменения (дельты) в стакане
                for price, qty, *_ in bids:
                    price_f = float(price)
                    qty_f = float(qty)
                    if qty_f == 0: # Если количество равно 0, убираем заявку
                        self.orderbooks[inst_id]['bids'].pop(price_f, None)
                    else: # Обновляем заявку
                        self.orderbooks[inst_id]['bids'][price_f] = qty_f
                
                for price, qty, *_ in asks: 
                    price_f = float(price)
                    qty_f = float(qty)
                    if qty_f == 0:
                        self.orderbooks[inst_id]['asks'].pop(price_f, None)
                    else:
                        self.orderbooks[inst_id]['asks'][price_f] = qty_f
                self.orderbooks[inst_id]['ts'] = ts # Обновляем время последнего изменения

            # Сохраняем данные в файл
            self.save_orderbook(inst_id)

    def save_orderbook(self, inst_id: str):
        # Сохраняем orderbook в формате JSON
        book = self.orderbooks.get(inst_id)
        if book:
            file_path = os.path.join(self.data_dir, f"{inst_id}_orderbook.json")
            with open(file_path, "w") as f:
                json.dump(book, f, indent=4)

    def get_top(self, inst_id: str, depth: int = 5) -> dict:
        # Метод для получения топовых заявок из стакана
        book = self.orderbooks.get(inst_id)
        return {
            'bids': list(reversed(book['bids'].items()))[:depth] if book else [],
            'asks': list(book['asks'].items())[:depth] if book else [],
            'ts': book['ts'] if book else None
        }

# %%
class OKXOrderBookCollector:
    def __init__(self):
        self.REST_URL = "https://www.okx.com/api/v5/public/instruments"
        self.WS_URL = "wss://ws.okx.com:8443/ws/v5/public"
        self.book_manager = OrderBookManager() # Менеджер для обработки и хранения данных о стаканах
        self.instruments: List[str] = [] # Список инструментов, на которые будем подписываться
        self.ws: aiohttp.ClientWebSocketResponse = None # WebSocket соединение
        self.session: aiohttp.ClientSession = None # HTTP сессия для запросов
        self.running = True

    @backoff.on_exception(backoff.expo, Exception, max_time=300) # Получение списка инструментов через REST API
    async def get_instruments(self):
        async with aiohttp.ClientSession() as session:
            async with session.get(self.REST_URL, params={'instType': 'SPOT'}) as resp:
                data = await resp.json()
                return [inst['instId'] for inst in data.get('data', [])]

    @backoff.on_exception(backoff.expo, aiohttp.ClientError, max_time=300)
    async def connect_websocket(self): # Подключение к WebSocket серверу
        if self.session is None or self.session.closed: # Если сессия закрыта, создаем новую
            self.session = aiohttp.ClientSession()
        self.ws = await self.session.ws_connect(
            self.WS_URL,
            heartbeat=30, # Период отправки heartbeat сообщений
            receive_timeout=60 # Время ожидания сообщений
        )
        logger.info("WebSocket connection established")

    async def subscribe_to_instruments(self):
        # Подписка на инструменты через WebSocket
        chunks = [self.instruments[i:i+20] for i in range(0, len(self.instruments), 20)]
        for chunk in chunks:
            sub_msg = {
                "op": "subscribe",
                "args": [{"channel": "books", "instId": inst} for inst in chunk]
            }
            await self.ws.send_json(sub_msg)
            logger.info(f"Subscribed to {len(chunk)} instruments")

    async def handle_message(self, msg: str):
        # Обработка сообщений, получаемых через WebSocket
        try:
            data = json.loads(msg) # Десериализация сообщения из JSON
            if 'event' in data:
                logger.info(f"Subscription update: {data}") # Логируем обновление подписки
                return

            if 'data' not in data or 'arg' not in data:
                return

            inst_id = data['arg']['instId']
            book_data = data['data'][0]
            await self.book_manager.process_book_data(inst_id, {
                'action': book_data.get('action', 'update'),
                'bids': book_data['bids'],
                'asks': book_data['asks'],
                'ts': book_data.get('ts')
            })

        except Exception as e:
            logger.error(f"Error processing message: {str(e)}", exc_info=True)

    async def start(self): # Основной метод для запуска процесса сбора данных
        try:
            self.instruments = await self.get_instruments() # Получаем список инструментов
            logger.info(f"Loaded {len(self.instruments)} instruments") # Логируем количество загруженных инструментов

            while self.running:
                try:
                    await self.connect_websocket() # Подключаемся к WebSocket
                    await self.subscribe_to_instruments() # Подписываемся на инструменты

                    async for msg in self.ws: # Получаем сообщения от WebSocket
                        if not self.running:
                            break
                        if msg.type == aiohttp.WSMsgType.TEXT: # Если тип сообщения - текст, обрабатываем его
                            await self.handle_message(msg.data)
                        elif msg.type == aiohttp.WSMsgType.PING: # Если получен ping, отвечаем pong
                            await self.ws.pong()
                        elif msg.type in (aiohttp.WSMsgType.CLOSED, aiohttp.WSMsgType.ERROR): # Если соединение закрыто или ошибка
                            raise ConnectionError("WebSocket connection closed")

                except (aiohttp.ClientError, ConnectionError) as e:
                    logger.warning(f"Connection error: {str(e)}, reconnecting...") # Логируем ошибку соединения и повторное подключение
                except Exception as e:
                    logger.error(f"Unexpected error: {str(e)}", exc_info=True) # Логируем другие неожиданные ошибки
                finally:
                    await self.close_websocket() # Закрываем WebSocket соединение
                    await asyncio.sleep(5) # Ждем перед повторным подключением

        except KeyboardInterrupt:
            logger.info("Shutting down gracefully...") # Логируем завершение работы
        finally:
            await self.close() # Закрываем все ресурсы

    async def close_websocket(self):
        # Закрытие WebSocket соединения
        if self.ws and not self.ws.closed:
            await self.ws.close()
            self.ws = None

    async def close(self): # Завершаем работу и закрываем все соединения
        self.running = False
        await self.close_websocket()
        if self.session and not self.session.closed:
            await self.session.close()
            self.session = None

    async def monitor_books(self, interval: int = 10):
        # Мониторим топовые заявки
        while self.running:
            for inst_id in (self.instruments[:3] if self.instruments else []):
                top = self.book_manager.get_top(inst_id)
                if top['ts']: # Логируем топовые заявки
                    logger.info(
                        f"{inst_id} | Bids: {[f'{p:.2f}:{q:.4f}' for p, q in top['bids'][:3]]} | "
                        f"Asks: {[f'{p:.2f}:{q:.4f}' for p, q in top['asks'][:3]]}"
                    )
            await asyncio.sleep(interval)

async def main(): # Главная асинхронная функция для запуска процесса
    collector = OKXOrderBookCollector()
    await asyncio.gather(
        collector.start(),
        collector.monitor_books()
    )

# %%
if __name__ == "__main__":
    nest_asyncio.apply()
    await main()
# Out:
# 2025-02-10 22:54:38,872 - INFO - Loaded 710 instruments
# 2025-02-10 22:54:39,698 - INFO - WebSocket connection established
# 2025-02-10 22:54:39,698 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,700 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,704 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,706 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,708 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,711 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,714 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,716 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,719 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,721 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,724 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,726 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,728 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,731 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,733 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,736 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,738 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,740 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,743 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,746 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,749 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,751 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,752 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,754 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,757 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,759 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,762 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,764 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,766 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,768 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,770 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,773 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,775 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,781 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,783 - INFO - Subscribed to 20 instruments
# 2025-02-10 22:54:39,785 - INFO - Subscribed to 10 instruments
# 2025-02-10 22:54:39,947 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BTC-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,948 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ETH-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,949 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SOL-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,951 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'DOGE-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,953 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'XRP-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,956 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'TRUMP-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,958 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BERA-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,960 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'LTC-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,961 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'AAVE-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,962 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ACH-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,965 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ANIME-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,967 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ARB-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,968 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ATH-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,969 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'AVAX-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,971 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BANANA-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,973 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BOME-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,975 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'CITY-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,978 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'COMP-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,980 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'CRV-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,982 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'DAI-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,984 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'DEGEN-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,987 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'DUCK-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,991 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ENS-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,994 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ETHFI-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,995 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'GOAT-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,997 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'GPT-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:39,999 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'JST-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,003 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'LINK-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,006 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ME-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,008 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'MEME-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,011 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'MERL-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,014 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'MEW-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,015 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'MKR-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,016 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'OL-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,020 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'OP-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,023 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'PENGU-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,026 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'PEPE-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,027 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'PIXEL-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,028 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'PRCL-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,029 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'RADAR-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,031 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'RAY-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,032 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'S-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,034 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SAFE-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,035 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SHIB-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,037 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SSV-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,041 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SUI-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,044 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ULTI-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,047 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'UNI-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,065 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'USDT-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,073 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'VELODROME-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,092 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'WIN-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,094 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'WLD-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,096 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'XR-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,097 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ZETA-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,100 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ZKJ-USD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,100 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'USDT-SGD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,102 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'USDC-SGD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,104 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BTC-AUD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,107 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ETH-AUD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,109 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SOL-AUD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,110 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'XRP-AUD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,112 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'TRUMP-AUD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,113 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'USDT-AUD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,114 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'USDC-AUD'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,116 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BTC-AED'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,118 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ETH-AED'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,119 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SOL-AED'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,121 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'XRP-AED'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,124 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'TRUMP-AED'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,126 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'USDT-AED'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,128 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BTC-BRL'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,129 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ETH-BRL'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,131 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SOL-BRL'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,132 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'XRP-BRL'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,133 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'TRUMP-BRL'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,135 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'PEPE-BRL'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,140 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'USDT-BRL'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,141 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'USDC-BRL'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,143 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BTC-EUR'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,144 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'ETH-EUR'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,147 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SOL-EUR'}, 'connId': 'bd021dbf'}
# 2025-02-10 22:54:40,148 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': '
- INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BCH-BTC'}, 'connId': '53f95358'}
# 2025-02-10 22:54:59,838 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BSV-BTC'}, 'connId': '53f95358'}
# 2025-02-10 22:54:59,840 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'STX-BTC'}, 'connId': '53f95358'}
# 2025-02-10 22:54:59,842 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'WBTC-BTC'}, 'connId': '53f95358'}
# 2025-02-10 22:54:59,844 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'SOL-ETH'}, 'connId': '53f95358'}
# 2025-02-10 22:54:59,846 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'BETH-ETH'}, 'connId': '53f95358'}
# 2025-02-10 22:54:59,847 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'STETH-ETH'}, 'connId': '53f95358'}
# 2025-02-10 22:54:59,849 - INFO - Subscription update: {'event': 'subscribe', 'arg': {'channel': 'books', 'instId': 'OKSOL-SOL'}, 'connId': '53f95358'}
# 2025-02-10 22:55:00,354 - INFO - BTC-USD | Bids: ['97345.00:0.1711', '97344.90:0.1027', '97343.70:0.4892'] | Asks: ['97358.40:0.0308', '97358.50:0.1027', '97363.10:0.0000']
# 2025-02-10 22:55:00,356 - INFO - ETH-USD | Bids: ['2670.85:1.0109', '2670.84:3.3697', '2670.66:0.0001'] | Asks: ['2671.45:0.0937', '2671.64:1.8285', '2671.65:5.9077']
# 2025-02-10 22:55:00,360 - INFO - SOL-USD | Bids: ['201.34:7.4501', '201.32:7.4505', '201.31:9.1017'] | Asks: ['201.36:3.8838', '201.37:7.4493', '201.38:0.0015']
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 if __name__ == "__main__":
#       2     nest_asyncio.apply()
# ----> 3     await main()
#
# Cell In[4], line 123, in main()
#     121 async def main(): # Главная асинхронная функция для запуска процесса
#     122     collector = OKXOrderBookCollector()
# --> 123     await asyncio.gather(
#     124         collector.start(),
#     125         collector.monitor_books()
#     126     )
#
# File c:\Python312\Lib\asyncio\tasks.py:316, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     314         result = coro.send(None)
#     315     else:
# --> 316         result = coro.throw(exc)
#     317 except StopIteration as exc:
#     318     if self._must_cancel:
#     319         # Task is cancelled right before coro stops.
#
# Cell In[4], line 119, in OKXOrderBookCollector.monitor_books(self, interval)
#     114     if top['ts']: # Логируем топовые заявки
#     115         logger.info(
#     116             f"{inst_id} | Bids: {[f'{p:.2f}:{q:.4f}' for p, q in top['bids'][:3]]} | "
#     117             f"Asks: {[f'{p:.2f}:{q:.4f}' for p, q in top['asks'][:3]]}"
#     118         )
# --> 119 await asyncio.sleep(interval)
#
# File c:\Python312\Lib\asyncio\tasks.py:665, in sleep(delay, result)
#     661 h = loop.call_later(delay,
#     662                     futures._set_result_unless_cancelled,
#     663                     future, result)
#     664 try:
# --> 665     return await future
#     666 finally:
#     667     h.cancel()
#
# File c:\Python312\Lib\asyncio\futures.py:287, in Future.__await__(self)
#     285 if not self.done():
#     286     self._asyncio_future_blocking = True
# --> 287     yield self  # This tells Task to wait for completion.
#     288 if not self.done():
#     289     raise RuntimeError("await wasn't used with future")
#
# File c:\Python312\Lib\asyncio\tasks.py:385, in Task.__wakeup(self, future)
#     383 def __wakeup(self, future):
#     384     try:
# --> 385         future.result()
#     386     except BaseException as exc:
#     387         # This may also be a cancellation.
#     388         self.__step(exc)
#
# File c:\Python312\Lib\asyncio\futures.py:198, in Future.result(self)
#     196 if self._state == _CANCELLED:
#     197     exc = self._make_cancelled_error()
# --> 198     raise exc
#     199 if self._state != _FINISHED:
#     200     raise exceptions.InvalidStateError('Result is not ready.')
#
# CancelledError:
